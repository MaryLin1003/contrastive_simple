# %%
# Google Colab 训练笔记本
# 叶廷凯：使用这个训练监督学习
# 林灵：改为 --model simclr
# 符武文：改为 --model moco

# [1] 安装依赖
# !pip install torch torchvision matplotlib scikit-learn pandas seaborn tqdm pyyaml -q

# [2] 下载代码
# !rm -rf contrastive_simple
# !git clone https://github.com/your-repo/contrastive_simple.git
# %cd contrastive_simple

# [3] 查看目录结构
# !ls -la

# [4] 训练模型（只需修改这一行！）
# 叶廷凯运行：
# !python train.py --model supervised --output ./results

# 林灵运行：
# !python train.py --model simclr --output ./results

# 符武文运行：
# !python train.py --model moco --output ./results

# [5] 查看训练结果
# !ls -la results/supervised/

# [6] 下载结果到本地
from google.colab import files
# !zip -r supervised_results.zip results/supervised/
files.download('supervised_results.zip')

print("✅ 训练完成！请将结果文件分享到群中")
